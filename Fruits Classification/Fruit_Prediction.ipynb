# %%
# %pwd
# Out:
# '/content'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/DSCT/Machine Learning/Fruits Classification
# Out:
# /content/drive/MyDrive/Colab Notebooks/DSCT/Machine Learning/Fruits Classification

# %%
# import lib
import numpy as np
import joblib
import pandas as pd 
import numpy as np 
import seaborn as sns
import cv2 
import os 
from matplotlib import pyplot as plt 
from sklearn.preprocessing import LabelEncoder

# %%
ML_Model=joblib.load("KNN_Model.pkl")
print("Loaded!!")
# Out:
# Loaded!!

# %%
le=joblib.load("Label_Encoder.pkl")
print("Loaded!!")
# Out:
# Loaded!!

# %%
ML_Model
# Out:
# KNeighborsClassifier(n_neighbors=3, p=1)

# %%
pred_dir='/content/drive/MyDrive/Colab Notebooks/Dataset/Fruit Classification/test/test/5579.jpg'

# %%
X_pred=[]
X_pred.append(cv2.resize(cv2.cvtColor(cv2.imread(f'{pred_dir}'), cv2.COLOR_BGR2GRAY), (50, 50)))

# %%
# X_pred=[]
# X_pred.append(cv2.resize(cv2.cvtColor(cv2.imread(f'{pred_dir}'), cv2.COLOR_BGR2RGB), (50, 50)))

# %%
plt.imshow(X_pred[0])

# %%
X_pred = np.asarray(X_pred)
X_pred.shape
# Out:
# (1, 50, 50)

# %%
X_pred = X_pred.reshape(X_pred.shape[0] , -1)
X_pred.shape
# Out:
# (1, 2500)

# %%
pred=ML_Model.predict(X_pred)[0]

# %%
pred
# Out:
# 0

# %%
prediction=le.inverse_transform([pred])

# %%
print('Predicited image is of :-',prediction[0])
# Out:
# Predicited image is of :- Apple Braeburn
